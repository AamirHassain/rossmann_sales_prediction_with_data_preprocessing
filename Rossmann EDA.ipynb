# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df_train = pd.read_csv('./train.csv', 
                       parse_dates=['Date'],
                       date_parser=(lambda dt: pd.to_datetime(dt, format='%d/%m/%Y')))

df_submit = pd.read_csv('./test.csv', 
                        parse_dates=['Date'],
                        date_parser=(lambda dt: pd.to_datetime(dt, format='%d/%m/%Y')))

df_store = pd.read_csv('./store.csv')

# %%
#Getting information on train data.
print(f'Shape of train dataset is {df_train.shape}. \n')
print('*'*50 + '\n')

df_train.info()
# Out:
# Shape of train dataset is (1017209, 9).
#
# **************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  datetime64[ns]
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 69.8+ MB

# %% [markdown]
# Here we can see that train dataset has no nul values right now.

# %%
#Getting information on store data.
print(f'Shape of train dataset is {df_store.shape}. \n')
print('*'*50 + '\n')

df_store.info()
# Out:
# Shape of train dataset is (1115, 10).
#
# **************************************************
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Store                      1115 non-null   int64
#  1   StoreType                  1115 non-null   object
#  2   Assortment                 1115 non-null   object
#  3   CompetitionDistance        1112 non-null   float64
#  4   CompetitionOpenSinceMonth  761 non-null    float64
#  5   CompetitionOpenSinceYear   761 non-null    float64
#  6   Promo2                     1115 non-null   int64
#  7   Promo2SinceWeek            571 non-null    float64
#  8   Promo2SinceYear            571 non-null    float64
#  9   PromoInterval              571 non-null    object
# dtypes: float64(5), int64(2), object(3)
# memory usage: 87.2+ KB

# %% [markdown]
# Here there are 5 features with null values. Now we will evaluate them and try to find the reason for the nul  values.

# %% [markdown]
# #Promo

# %%
fig, (axis1,axis2) = plt.subplots(1,2,figsize=(20,4))

axis1.title.set_text('Promo vs.Sales')
axis2.title.set_text('Promo vs.Customers')
sns.barplot(x='Promo', y='Sales', data=df_train, ax=axis1)
sns.barplot(x='Promo', y='Customers', data=df_train, ax=axis2)
# Out:
# <AxesSubplot:title={'center':'Promo vs.Customers'}, xlabel='Promo', ylabel='Customers'>

# %% [markdown]
# **Obseravtions:**
#
# Here we observe that both Sales and Customers increases by a significant amount during Promotions. This shows that Promotion has a positive effect for a store.

# %% [markdown]
# #Date Features

# %%
#Extracting some date features for analysis.
df_train['Year'] = df_train['Date'].dt.year
df_train['Month'] = df_train['Date'].dt.month
df_train['Day'] = df_train['Date'].dt.day
df_train['WeekOfYear'] = df_train['Date'].dt.weekofyear

# %%
# group by date and get average sales, and precent change
average_sales    = df_train.groupby('WeekOfYear')["Sales"].mean()
pct_change_sales = df_train.groupby('WeekOfYear')["Sales"].sum().pct_change()

fig, (axis1,axis2) = plt.subplots(2,1,sharex=True,figsize=(15,8))

# plot average sales over time(year-month)
ax1 = average_sales.plot(legend=True, ax=axis1, marker='o', title="Average Sales Per Week.")
ax1.set_xticks(range(len(average_sales)))
ax1.set_xticklabels(average_sales.index.tolist())
ax1.set_ylabel('Sales', size=12)

# plot precent change for sales over time(year-month)
ax2 = pct_change_sales.plot(legend=True, ax=axis2, marker='o', colormap="summer", title="Sales Percent Change Per Week.")
plt.ylabel("Sales", size=12)
plt.xlabel('Week Of Year', size=12)
# Out:
# Text(0.5, 0, 'Week Of Year')

# %%
# DayOfWeek
# In both cases where the store is closed and opened.

fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,4))

sns.barplot(x='DayOfWeek', y='Sales', data=df_train, order=[1,2,3,4,5,6,7], ax=axis1)
sns.barplot(x='DayOfWeek', y='Customers', data=df_train, order=[1,2,3,4,5,6,7], ax=axis2)
# Out:
# <AxesSubplot:xlabel='DayOfWeek', ylabel='Customers'>

# %% [markdown]
# **Observations:**
# Here we observe that Sales and Customers are both very less on Sundays as most of the stores are closed on Sunday.
#
# Also, Sales on Monday is highest in whole week. This might be due to the fact that stores are closed on Sundays.
#
# It is also interesting to note that Christmas and New Year lead to increase in sales. As Rossmann Stores sells health and beauty products, it may be guessed that during Christmas and New Year people buy beauty products as they go out to celebrate and, this might the cause of sudden increase in sales.

# %% [markdown]
# #Open Column.

# %%
fig, (axis1) = plt.subplots(1,1,figsize=(15,4))
sns.countplot(x='Open',hue='DayOfWeek', data=df_train,palette="husl", ax=axis1)
# Out:
# <AxesSubplot:xlabel='Open', ylabel='count'>

# %% [markdown]
# **Observations:**
#
# This clearly shows that most of the stores remain closed during Sundays. Some stores were closed in weekdays too, this might be due to State Holidays as stores are generally closed during State Holidays and opened during School Holidays.

# %% [markdown]
# #State and Schoool Holiday.

# %%
#State Holiday.
df_train["StateHoliday"] = df_train["StateHoliday"].map({0: 0, "0": 0, "a": 1, "b": 1, "c": 1})

fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,4))

sns.barplot(x='StateHoliday', y='Sales', data=df_train, ax=axis1)
sns.barplot(x='StateHoliday', y='Customers', data=df_train, ax=axis2)
# Out:
# <AxesSubplot:xlabel='StateHoliday', ylabel='Customers'>

# %%
#School Holiday.
sns.countplot(x='SchoolHoliday', data=df_train)

fig, (axis1,axis2) = plt.subplots(1,2,figsize=(15,4))

sns.barplot(x='SchoolHoliday', y='Sales', data=df_train, ax=axis1)
sns.barplot(x='SchoolHoliday', y='Customers', data=df_train, ax=axis2)
# Out:
# <AxesSubplot:xlabel='SchoolHoliday', ylabel='Customers'>

# %% [markdown]
# **Observations:**
#
# We can observe that most of the stores remain closed during State and School Holidays. But it is interesting to note that the number of stores opened during School Holidays were more than that were opened during State Holidays.
#
# Another important thing to note is that the stores which were opened during School holidays had more sales than normal.

# %%
#Joining store data and train data.
df = pd.merge(df_train, df_store, how='left', on='Store')

# %% [markdown]
# #Store Types.

# %%
df.groupby('StoreType')['Sales'].describe()
# Out:
#               count          mean          std  min     25%     50%       75%  \
# StoreType
# a          551627.0   5738.179710  3964.028134  0.0  3508.0  5618.0   7860.00
# b           15830.0  10058.837334  5280.525506  0.0  6227.0  9025.5  13082.75
# c          136840.0   5723.629246  3721.700886  0.0  3789.0  5766.0   7849.00
# d          312912.0   5641.819243  3473.393781  0.0  3986.0  5826.0   7691.00
#
#                max
# StoreType
# a          41551.0
# b          38722.0
# c          31448.0
# d          38037.0

# %%
df.groupby('StoreType')['Customers', 'Sales'].sum()
# Out:
#            Customers       Sales
# StoreType
# a          363541434  3165334859
# b           31465621   159231395
# c           92129705   783221426
# d          156904995  1765392943

# %% [markdown]
# **Observations:**
#
# Stores of type B has the highest average of Sales among others but, we have much less data for StoreType B.
#
# But as we see further stores of type A has higher amount of total Customers and Sales. StoreType D goes on the second place in both Sales and Customers.

# %% [markdown]
# #Checking duration of Promo.

# %%
df_store_1 = df.loc[df['Store']==1]

# %%
df_store_1.sort_values('Date', inplace=True)
df_store_1.head(50)
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
#
ompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 1016095                    2008.0       0              NaN              NaN
# 1014980                    2008.0       0              NaN              NaN
# 1013865                    2008.0       0              NaN              NaN
# 1012750                    2008.0       0              NaN              NaN
# 1011635                    2008.0       0              NaN              NaN
# 1010520                    2008.0       0              NaN              NaN
# 1009405                    2008.0       0              NaN              NaN
# 1008290                    2008.0       0              NaN              NaN
# 1007175                    2008.0       0              NaN              NaN
# 1006060                    2008.0       0              NaN              NaN
# 1004945                    2008.0       0              NaN              NaN
# 1003830                    2008.0       0              NaN              NaN
# 1002715                    2008.0       0              NaN              NaN
# 1001600                    2008.0       0              NaN              NaN
# 1000485                    2008.0       0              NaN              NaN
# 999370                     2008.0       0              NaN              NaN
# 998255                     2008.0       0              NaN              NaN
# 997140                     2008.0       0              NaN              NaN
# 996025                     2008.0       0              NaN              NaN
# 994910                     2008.0       0              NaN              NaN
# 993795                     2008.0       0              NaN              NaN
# 992680                     2008.0       0              NaN              NaN
# 991565                     2008.0       0              NaN              NaN
# 990450                     2008.0       0              NaN              NaN
# 989335                     2008.0       0              NaN              NaN
# 988220                     2008.0       0              NaN              NaN
# 987105                     2008.0       0              NaN              NaN
# 985990                     2008.0       0              NaN              NaN
# 984875                     2008.0       0              NaN              NaN
# 983760                     2008.0       0              NaN              NaN
# 982645                     2008.0       0              NaN              NaN
# 981530                     2008.0       0              NaN              NaN
# 980415                     2008.0       0              NaN              NaN
# 979300                     2008.0       0              NaN              NaN
# 978185                     2008.0       0              NaN              NaN
# 977070                     2008.0       0              NaN              NaN
# 975955                     2008.0       0              NaN              NaN
# 974840                     2008.0       0              NaN              NaN
# 973725                     2008.0       0              NaN              NaN
# 972610                     2008.0       0              NaN              NaN
# 971495                     2008.0       0              NaN              NaN
# 970380                     2008.0       0              NaN              NaN
# 969265                     2008.0       0              NaN              NaN
# 968150                     2008.0       0              NaN              NaN
# 967035                     2008.0       0              NaN              NaN
# 965920                     2008.0       0              NaN              NaN
# 964805                     2008.0       0              NaN              NaN
# 963690                     2008.0       0              NaN              NaN
# 962575                     2008.0       0              NaN              NaN
# 961460                     2008.0       0              NaN              NaN
#
#          PromoInterval
# 1016095            NaN
# 1014980            NaN
# 1013865            NaN
# 1012750            NaN
# 1011635            NaN
# 1010520            NaN
# 1009405            NaN
# 1008290            NaN
# 1007175            NaN
# 1006060            NaN
# 1004945            NaN
# 1003830            NaN
# 1002715            NaN
# 1001600            NaN
# 1000485            NaN
# 999370             NaN
# 998255             NaN
# 997140             NaN
# 996025             NaN
# 994910             NaN
# 993795             NaN
# 992680             NaN
# 991565             NaN
# 990450             NaN
# 989335             NaN
# 988220             NaN
# 987105             NaN
# 985990             NaN
# 984875             NaN
# 983760             NaN
# 982645             NaN
# 981530             NaN
# 980415             NaN
# 979300             NaN
# 978185             NaN
# 969266                     2007.0       1             13.0           2010.0
# 968151                     2007.0       1             13.0           2010.0
# 967036                     2007.0       1             13.0           2010.0
# 965921                     2007.0       1             13.0           2010.0
# 964806                     2007.0       1             13.0           2010.0
# 963691                     2007.0       1             13.0           2010.0
# 962576                     2007.0       1             13.0           2010.0
# 961461                     2007.0       1             13.0           2010.0
# 960346                     2007.0       1             13.0           2010.0
# 959231                     2007.0       1             13.0           2010.0
# 958116                     2007.0       1             13.0           2010.0
# 957001                     2007.0       1             13.0           2010.0
# 955886                     2007.0       1             13.0           2010.0
#
#            PromoInterval
# 1016096  Jan,Apr,Jul,Oct
# 1014981  Jan,Apr,Jul,Oct
# 1013866  Jan,Apr,Jul,Oct
# 1012751  Jan,Apr,Jul,Oct
# 1011636  Jan,Apr,Jul,Oct
# 1010521  Jan,Apr,Jul,Oct
# 1009406  Jan,Apr,Jul,Oct
# 1008291  Jan,Apr,Jul,Oct
# 1007176  Jan,Apr,Jul,Oct
# 1006061  Jan,Apr,Jul,Oct
# 1004946  Jan,Apr,Jul,Oct
# 1003831  Jan,Apr,Jul,Oct
# 1002716  Jan,Apr,Jul,Oct
# 1001601  Jan,Apr,Jul,Oct
# 1000486  Jan,Apr,Jul,Oct
# 999371   Jan,Apr,Jul,Oct
# 998256   Jan,Apr,Jul,Oct
# 997141   Jan,Apr,Jul,Oct
# 996026   Jan,Apr,Jul,Oct
# 994911   Jan,Apr,Jul,Oct
# 993796   Jan,Apr,Jul,Oct
# 992681   Jan,Apr,Jul,Oct
# 991566   Jan,Apr,Jul,Oct
# 990451   Jan,Apr,Jul,Oct
# 989336   Jan,Apr,Jul,Oct
# 988221   Jan,Apr,Jul,Oct
# 987106   Jan,Apr,Jul,Oct
# 985991   Jan,Apr,Jul,Oct
# 984876   Jan,Apr,Jul,Oct
# 983761   Jan,Apr,Jul,Oct
# 982646   Jan,Apr,Jul,Oct
# 981531   Jan,Apr,Jul,Oct
# 980416   Jan,Apr,Jul,Oct
# 979301   Jan,Apr,Jul,Oct
# 978186   Jan,Apr,Jul,Oct
# 977071   Jan,Apr,Jul,Oct
# 975956   Jan,Apr,Jul,Oct
# 974841   Jan,Apr,Jul,Oct
# 973726   Jan,Apr,Jul,Oct
# 972611   Jan,Apr,Jul,Oct
# 971496   Jan,Apr,Jul,Oct
# 970381   Jan,Apr,Jul,Oct
# 969266   Jan,Apr,Jul,Oct
# 968151   Jan,Apr,Jul,Oct
# 967036   Jan,Apr,Jul,Oct
# 965921   Jan,Apr,Jul,Oct
# 964806   Jan,Apr,Jul,Oct
# 963691   Jan,Apr,Jul,Oct
# 962576   Jan,Apr,Jul,Oct
# 961461   Jan,Apr,Jul,Oct
# 960346   Jan,Apr,Jul,Oct
# 959231   Jan,Apr,Jul,Oct
# 958116   Jan,Apr,Jul,Oct
# 957001   Jan,Apr,Jul,Oct
# 955886   Jan,Apr,Jul,Oct
#
# [55 rows x 22 columns]

# %%
df_store_2.loc[df_store_2['Month']>3].head(60)
# Out:
#         Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
#
# 871146                    2007.0       1             13.0           2010.0
# 870031                    2007.0       1             13.0           2010.0
# 868916                    2007.0       1             13.0           2010.0
# 867801                    2007.0       1             13.0           2010.0
# 866686                    2007.0       1             13.0           2010.0
# 865571                    2007.0       1             13.0           2010.0
# 864456                    2007.0       1             13.0           2010.0
# 863341                    2007.0       1             13.0           2010.0
# 862226                    2007.0       1             13.0           2010.0
# 861111                    2007.0       1             13.0           2010.0
# 859996                    2007.0       1             13.0           2010.0
# 858881                    2007.0       1             13.0           2010.0
# 857766                    2007.0       1             13.0           2010.0
# 856651                    2007.0       1             13.0           2010.0
# 855536                    2007.0       1             13.0           2010.0
# 854421                    2007.0       1             13.0           2010.0
# 853306                    2007.0       1             13.0           2010.0
# 852191                    2007.0       1             13.0           2010.0
# 851076                    2007.0       1             13.0           2010.0
# 849961                    2007.0       1             13.0           2010.0
#
#           PromoInterval
# 915746  Jan,Apr,Jul,Oct
# 914631  Jan,Apr,Jul,Oct
# 913516  Jan,Apr,Jul,Oct
# 912401  Jan,Apr,Jul,Oct
# 911286  Jan,Apr,Jul,Oct
# 910171  Jan,Apr,Jul,Oct
# 909056  Jan,Apr,Jul,Oct
# 907941  Jan,Apr,Jul,Oct
# 906826  Jan,Apr,Jul,Oct
# 905711  Jan,Apr,Jul,Oct
# 904596  Jan,Apr,Jul,Oct
# 903481  Jan,Apr,Jul,Oct
# 902366  Jan,Apr,Jul,Oct
# 901251  Jan,Apr,Jul,Oct
# 900136  Jan,Apr,Jul,Oct
# 899021  Jan,Apr,Jul,Oct
# 897906  Jan,Apr,Jul,Oct
# 896791  Jan,Apr,Jul,Oct
# 895676  Jan,Apr,Jul,Oct
# 894561  Jan,Apr,Jul,Oct
# 893446  Jan,Apr,Jul,Oct
# 892331  Jan,Apr,Jul,Oct
# 891216  Jan,Apr,Jul,Oct
# 890101  Jan,Apr,Jul,Oct
# 888986  Jan,Apr,Jul,Oct
# 887871  Jan,Apr,Jul,Oct
# 886756  Jan,Apr,Jul,Oct
# 885641  Jan,Apr,Jul,Oct
# 884526  Jan,Apr,Jul,Oct
# 883411  Jan,Apr,Jul,Oct
# 882296  Jan,Apr,Jul,Oct
# 881181  Jan,Apr,Jul,Oct
# 880066  Jan,Apr,Jul,Oct
# 878951  Jan,Apr,Jul,Oct
# 877836  Jan,Apr,Jul,Oct
# 876721  Jan,Apr,Jul,Oct
# 875606  Jan,Apr,Jul,Oct
# 874491  Jan,Apr,Jul,Oct
# 873376  Jan,Apr,Jul,Oct
# 872261  Jan,Apr,Jul,Oct
# 871146  Jan,Apr,Jul,Oct
# 870031  Jan,Apr,Jul,Oct
# 868916  Jan,Apr,Jul,Oct
# 867801  Jan,Apr,Jul,Oct
# 866686  Jan,Apr,Jul,Oct
# 865571  Jan,Apr,Jul,Oct
# 864456  Jan,Apr,Jul,Oct
# 863341  Jan,Apr,Jul,Oct
# 862226  Jan,Apr,Jul,Oct
# 861111  Jan,Apr,Jul,Oct
# 859996  Jan,Apr,Jul,Oct
# 1004944           c              5350.0                       NaN
# 1003829           c              5350.0                       NaN
# 1002714           c              5350.0                       NaN
# 1001599           c              5350.0                       NaN
# 1000484           c              5350.0                       NaN
# 999369            c              5350.0                       NaN
# 998254            c              5350.0                       NaN
# 997139            c              5350.0                       NaN
# 996024            c              5350.0                       NaN
# 994909            c              5350.0                       NaN
# 993794            c              5350.0                       NaN
# 992679            c              5350.0                       NaN
# 991564            c              5350.0                       NaN
# 990449            c              5350.0                       NaN
# 989334            c              5350.0                       NaN
# 988219            c              5350.0                       NaN
# 987104            c              5350.0                       NaN
# 985989            c              5350.0                       NaN
# 984874            c              5350.0                       NaN
# 983759            c              5350.0                       NaN
# 982644            c              5350.0                       NaN
# 981529            c              5350.0                       NaN
# 980414            c              5350.0                       NaN
# 979299            c              5350.0                       NaN
# 978184            c              5350.0                       NaN
# 977069            c              5350.0                       NaN
# 975954            c              5350.0                       NaN
# 974839            c              5350.0                       NaN
# 973724            c              5350.0                       NaN
# 972609            c              5350.0                       NaN
# 971494            c              5350.0                       NaN
# 970379            c              5350.0                       NaN
# 969264            c              5350.0                       NaN
# 968149            c              5350.0                       NaN
# 967034            c              5350.0                       NaN
# 965919            c              5350.0                       NaN
# 964804            c              5350.0                       NaN
# 963689            c              5350.0                       NaN
# 962574            c              5350.0                       NaN
# 961459            c              5350.0                       NaN
# 960344            c              5350.0                       NaN
# 959229            c              5350.0                       NaN
# 958114            c              5350.0                       NaN
# 956999            c              5350.0                       NaN
#
#          CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 1017208                       NaN       1             22.0           2012.0
# 1016094                       NaN       1             22.0           2012.0
# 1014979                       NaN       1             22.0           2012.0
# 1013864                       NaN       1             22.0           2012.0
# 1012749                       NaN       1             22.0           2012.0
# 1011634                       NaN       1             22.0           2012.0
# 1010519                       NaN       1             22.0           2012.0
# 1009404                       NaN       1             22.0           2012.0
# 1008289                       NaN       1             22.0           2012.0
# 1007174                       NaN       1             22.0           2012.0
# 1006059                       NaN       1             22.0           2012.0
# 1004944                       NaN       1             22.0           2012.0
# 1003829                       NaN       1             22.0           2012.0
# 1002714                       NaN       1             22.0           2012.0
# 1001599                       NaN       1             22.0           2012.0
# 1000484                       NaN       1             22.0           2012.0
# 999369                        NaN       1             22.0           2012.0
# 998254                        NaN       1             22.0           2012.0
# 997139                        NaN       1             22.0           2012.0
# 996024                        NaN       1             22.0           2012.0
# 994909                        NaN       1             22.0           2012.0
# 993794                        NaN       1             22.0           2012.0
# 992679                        NaN       1             22.0           2012.0
# 991564                        NaN       1             22.0           2012.0
# 990449                        NaN       1             22.0           2012.0
# 989334                        NaN       1             22.0           2012.0
# 988219                        NaN       1             22.0           2012.0
# 987104                        NaN       1             22.0           2012.0
# 985989                        NaN       1             22.0           2012.0
# 984874                        NaN       1             22.0           2012.0
# 983759                        NaN       1             22.0           2012.0
# 982644                        NaN       1             22.0           2012.0
# 981529                        NaN       1             22.0           2012.0
# 980414                        NaN       1             22.0           2012.0
# 979299                        NaN       1             22.0           2012.0
# 978184                        NaN       1             22.0           2012.0
# 977069                        NaN       1             22.0           2012.0
# 975954                        NaN       1             22.0           2012.0
# 974839                        NaN       1             22.0           2012.0
# 973724                        NaN       1             22.0           2012.0
# 972609                        NaN       1             22.0           2012.0
# 971494                        NaN       1             22.0           2012.0
# 970379                        NaN       1             22.0           2012.0
# 969264                        NaN       1             22.0           2012.0
# 968149                        NaN       1             22.0           2012.0
# 967034                        NaN       1             22.0           2012.0
# 965919                        NaN       1             22.0           2012.0
# 964804                        NaN       1             22.0           2012.0
# 963689                        NaN       1             22.0           2012.0
# 962574                        NaN       1             22.0           2012.0
# 961459                        NaN       1             22.0           2012.0
# 960344                        NaN       1             22.0           2012.0
# 959229                        NaN       1             22.0           2012.0
# 958114                        NaN       1             22.0           2012.0
# 956999                        NaN       1             22.0           2012.0
#
#             PromoInterval
# 1017208  Mar,Jun,Sept,Dec
# 1016094  Mar,Jun,Sept,Dec
# 1014979  Mar,Jun,Sept,Dec
# 1013864  Mar,Jun,Sept,Dec
# 1012749  Mar,Jun,Sept,Dec
# 1011634  Mar,Jun,Sept,Dec
# 1010519  Mar,Jun,Sept,Dec
# 1009404  Mar,Jun,Sept,Dec
# 1008289  Mar,Jun,Sept,Dec
# 1007174  Mar,Jun,Sept,Dec
# 1006059  Mar,Jun,Sept,Dec
# 1004944  Mar,Jun,Sept,Dec
# 1003829  Mar,Jun,Sept,Dec
# 1002714  Mar,Jun,Sept,Dec
# 1001599  Mar,Jun,Sept,Dec
# 1000484  Mar,Jun,Sept,Dec
# 999369   Mar,Jun,Sept,Dec
# 998254   Mar,Jun,Sept,Dec
# 997139   Mar,Jun,Sept,Dec
# 996024   Mar,Jun,Sept,Dec
# 994909   Mar,Jun,Sept,Dec
# 993794   Mar,Jun,Sept,Dec
# 992679   Mar,Jun,Sept,Dec
# 991564   Mar,Jun,Sept,Dec
# 990449   Mar,Jun,Sept,Dec
# 989334   Mar,Jun,Sept,Dec
# 988219   Mar,Jun,Sept,Dec
# 987104   Mar,Jun,Sept,Dec
# 985989   Mar,Jun,Sept,Dec
# 984874   Mar,Jun,Sept,Dec
# 983759   Mar,Jun,Sept,Dec
# 982644   Mar,Jun,Sept,Dec
# 981529   Mar,Jun,Sept,Dec
# 980414   Mar,Jun,Sept,Dec
# 979299   Mar,Jun,Sept,Dec
# 978184   Mar,Jun,Sept,Dec
# 977069   Mar,Jun,Sept,Dec
# 975954   Mar,Jun,Sept,Dec
# 974839   Mar,Jun,Sept,Dec
# 973724   Mar,Jun,Sept,Dec
# 972609   Mar,Jun,Sept,Dec
# 971494   Mar,Jun,Sept,Dec
# 970379   Mar,Jun,Sept,Dec
# 969264   Mar,Jun,Sept,Dec
# 968149   Mar,Jun,Sept,Dec
# 967034   Mar,Jun,Sept,Dec
# 965919   Mar,Jun,Sept,Dec
# 964804   Mar,Jun,Sept,Dec
# 963689   Mar,Jun,Sept,Dec
# 962574   Mar,Jun,Sept,Dec
# 961459   Mar,Jun,Sept,Dec
# 960344   Mar,Jun,Sept,Dec
# 959229   Mar,Jun,Sept,Dec
# 958114   Mar,Jun,Sept,Dec
# 956999   Mar,Jun,Sept,Dec
#
# [55 rows x 22 columns]

# %% [markdown]
# **Observations:**
#
# Here we can see that store has a promo period of 5 days and whenever there's a promo, it happens for two times in a month. Thus, as we have seen in 'Promo' analysis that promo increases sales, we can expect that the month with Promo equal to 1, will have 10 days where sales will be more than regular times.

# %% [markdown]
# #Checking seasonalities using Fourier transform features.

# %%
df.loc[df['Store']==1115]
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 1114      1115          5 2015-07-31   8680        538     1      1
# 2229      1115          4 2015-07-30   8405        502     1      1
# 3344      1115          3 2015-07-29   7661        473     1      1
# 4459      1115          2 2015-07-28   8093        500     1      1
# 5574      1115          1 2015-07-27  10712        608     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1012749   1115          6 2013-01-05   4771        339     1      0
# 1013864   1115          5 2013-01-04   4540        326     1      0
# 1014979   1115          4 2013-01-03   4297        300     1      0
# 1016094   1115          3 2013-01-02   3697        305     1      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#          StateHoliday  SchoolHoliday  Year  ...  WeekOfYear  StoreType  \
# 1114                0              1  2015  ...          31          d
# 2229                0              1  2015  ...          31          d
# 3344                0              1  2015  ...          31          d
# 4459                0              1  2015  ...          31          d
# 5574                0              1  2015  ...          31          d
# ...               ...            ...   ...  ...         ...        ...
# 1012749             0              1  2013  ...           1          d
# 1013864             0              1  2013  ...           1          d
# 1014979             0              1  2013  ...           1          d
# 1016094             0              1  2013  ...           1          d
# 1017208             1              1  2013  ...           1          d
#
#          Assortment CompetitionDistance CompetitionOpenSinceMonth  \
# 1114              c              5350.0                       NaN
# 2229              c              5350.0                       NaN
# 3344              c              5350.0                       NaN
# 4459              c              5350.0                       NaN
# 5574              c              5350.0                       NaN
# ...             ...                 ...                       ...
# 1012749           c              5350.0                       NaN
# 1013864           c              5350.0                       NaN
# 1014979           c              5350.0                       NaN
# 1016094           c              5350.0                       NaN
# 1017208           c              5350.0                       NaN
#
#          CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 1114                          NaN       1             22.0           2012.0
# 2229                          NaN       1             22.0           2012.0
# 3344                          NaN       1             22.0           2012.0
# 4459                          NaN       1             22.0           2012.0
# 5574                          NaN       1             22.0           2012.0
# ...                           ...     ...              ...              ...
# 1012749                       NaN       1             22.0           2012.0
# 1013864                       NaN       1             22.0           2012.0
# 1014979                       NaN       1             22.0           2012.0
# 1016094                       NaN       1             22.0           2012.0
# 1017208                       NaN       1             22.0           2012.0
#
#             PromoInterval
# 1114     Mar,Jun,Sept,Dec
# 2229     Mar,Jun,Sept,Dec
# 3344     Mar,Jun,Sept,Dec
# 4459     Mar,Jun,Sept,Dec
# 5574     Mar,Jun,Sept,Dec
# ...                   ...
# 1012749  Mar,Jun,Sept,Dec
# 1013864  Mar,Jun,Sept,Dec
# 1014979  Mar,Jun,Sept,Dec
# 1016094  Mar,Jun,Sept,Dec
# 1017208  Mar,Jun,Sept,Dec
#
# [942 rows x 22 columns]

# %%
#Considering store 11 which is of type 'a'
df_store_11_sales = df.loc[df['Store']==11]['Sales']
Y    = np.fft.fft(df_store_11_sales.values)
freq = np.fft.fftfreq(len(Y), 1)
n = len(freq)

plt.figure()
plt.plot( freq[:int(n/2)], np.abs(Y)[:int(n/2)] )

plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.ticklabel_format(style='plain', axis='y')
plt.title("Discrete Fourier Transform for Store 11 (Store type 'a')")
plt.show()

# %%
#Store Type 'B'.
df_store_259_sales = df.loc[df['Store']==259]['Sales']

# getting peaks: https://blog.ytotech.com/2015/11/01/findpeaks-in-python/
# read more about fft function : https://docs.scipy.org/doc/numpy/reference/generated/numpy.fft.fft.html
Y = np.fft.fft(df_store_259_sales.values)
# read more about the fftfreq: https://docs.scipy.org/doc/numpy/reference/generated/numpy.fft.fftfreq.html  
freq = np.fft.fftfreq(len(Y), 1)
n = len(freq)
plt.figure()
plt.plot( freq[:int(n/2)], np.abs(Y)[:int(n/2)] )
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.ticklabel_format(style='plain', axis='y')
plt.title("Discrete Fourier Transform for Store 259 (Store type 'b')")
plt.show()

# %%
#Store Type 'C'.
df_store_21_sales = df.loc[df['Store']==21]['Sales']

# getting peaks: https://blog.ytotech.com/2015/11/01/findpeaks-in-python/
# read more about fft function : https://docs.scipy.org/doc/numpy/reference/generated/numpy.fft.fft.html
Y    = np.fft.fft(df_store_21_sales.values)
# read more about the fftfreq: https://docs.scipy.org/doc/numpy/reference/generated/numpy.fft.fftfreq.html  
freq = np.fft.fftfreq(len(Y), 1)
n = len(freq)
plt.figure()
plt.plot( freq[:int(n/2)], np.abs(Y)[:int(n/2)] )
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.ticklabel_format(style='plain', axis='y')
plt.title("Discrete Fourier Transform for Store 21 (Store type 'c')")
plt.show()

# %%
#Store Type 'D'.
df_store_1115_sales = df.loc[df['Store']==1115]['Sales']

# getting peaks: https://blog.ytotech.com/2015/11/01/findpeaks-in-python/
# read more about fft function : https://docs.scipy.org/doc/numpy/reference/generated/numpy.fft.fft.html
Y    = np.fft.fft(df_store_1115_sales.values)
# read more about the fftfreq: https://docs.scipy.org/doc/numpy/reference/generated/numpy.fft.fftfreq.html  
freq = np.fft.fftfreq(len(Y), 1)
n = len(freq)
plt.figure()
plt.plot( freq[:int(n/2)], np.abs(Y)[:int(n/2)] )
plt.xlabel("Frequency")
plt.ylabel("Amplitude")
plt.ticklabel_format(style='plain', axis='y')
plt.title("Discrete Fourier Transform for Store 1115 (Store type 'd')")
plt.show()

# %% [markdown]
# **Observations:**
#
# In the above graphs we can see that there are some spikes at particular frequencies. This indicates that there is a seasonality component in the store sales data.
#
# Thus we can use these Fourier features to indicate the seasonality in the data.

# %% [markdown]
# #Competition Open Since Year/Month.

# %%
percent_year = 100 * (len(df_store.loc[pd.isnull(df_store['CompetitionOpenSinceYear'])])) / len(df_store)
percent_month = 100 * (len(df_store.loc[pd.isnull(df_store['CompetitionOpenSinceMonth'])])) / len(df_store)

print(f'The percent of missing values in Competition Open Since Year feature is {percent_year}.')
print(f'The percent of missing values in Competition Open Since Month feature is {percent_month}.')
# Out:
# The percent of missing values in Competition Open Since Year feature is 31.748878923766817.
# The percent of missing values in Competition Open Since Month feature is 31.748878923766817.

# %%
df_store.loc[pd.isnull(df_store['CompetitionOpenSinceYear'])]
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 11       12         a          c               1070.0
# 12       13         d          a                310.0
# 15       16         a          c               3270.0
# 18       19         a          c               3240.0
# 21       22         a          a               1040.0
# ...     ...       ...        ...                  ...
# 1095   1096         a          c               1130.0
# 1099   1100         a          a                540.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 11                          NaN                       NaN       1
# 12                          NaN                       NaN       1
# 15                          NaN                       NaN       0
# 18                          NaN                       NaN       1
# 21                          NaN                       NaN       1
# ...                         ...                       ...     ...
# 1095                        NaN                       NaN       1
# 1099                        NaN                       NaN       1
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 11               13.0           2010.0   Jan,Apr,Jul,Oct
# 12               45.0           2009.0   Feb,May,Aug,Nov
# 15                NaN              NaN               NaN
# 18               22.0           2011.0  Mar,Jun,Sept,Dec
# 21               22.0           2012.0   Jan,Apr,Jul,Oct
# ...               ...              ...               ...
# 1095             10.0           2014.0  Mar,Jun,Sept,Dec
# 1099             14.0           2011.0   Jan,Apr,Jul,Oct
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [354 rows x 10 columns]

# %%
sns.distplot(df_store['CompetitionOpenSinceYear'])
# Out:
# <AxesSubplot:xlabel='CompetitionOpenSinceYear', ylabel='Density'>

# %%
year_median = df_store['CompetitionOpenSinceYear'].median()
print(f'Most of stores have their competition opened in the year {year_median}.')
# Out:
# Most of stores have their competition opened in the year 2010.0.

# %%
sns.distplot(df_store['CompetitionOpenSinceMonth'])
# Out:
# <AxesSubplot:xlabel='CompetitionOpenSinceMonth', ylabel='Density'>

# %%
month_median = df_store['CompetitionOpenSinceMonth'].median()
print(f'Most of stores have their competition opened in the month {month_median}.')
# Out:
# Most of stores have their competition opened in the month 8.0.

# %% [markdown]
# #CompetitionDistance.

# %%
df_store.loc[pd.isnull(df_store['CompetitionDistance'])]
# Out:
#      Store StoreType Assortment  CompetitionDistance  \
# 290    291         d          a                  NaN
# 621    622         a          c                  NaN
# 878    879         d          a                  NaN
#
#      CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 290                        NaN                       NaN       0
# 621                        NaN                       NaN       0
# 878                        NaN                       NaN       1
#
#      Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 290              NaN              NaN              NaN
# 621              NaN              NaN              NaN
# 878              5.0           2013.0  Feb,May,Aug,Nov

# %%
#Plotting distribution of Competition Distance.
sns.distplot(df_store['CompetitionDistance'])
plt.xlabel('Competition Distance in meters',fontsize=11.5)
# Out:
# Text(0.5, 0, 'Competition Distance in meters')

# %% [markdown]
# In this figure we can see that most of the stores have their competition within 5km range.

# %% [markdown]
# **Observations:**
#
# It is interesting to note that missing values in CompetitionOpenYear/Month doesn't indicate that there's no competiotion near the store as the value of  CompetitionDistance is not null where the CompetitionOpenYear/Month is null.
#
# Thus they are not dependent on each other and absence of one value doesn't indicate that other will be absent.

# %% [markdown]
# #Promo2SinceWeek

# %%
df.head()
# Out:
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo  StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1             0
# 1      2          5 2015-07-31   6064        625     1      1             0
# 2      3          5 2015-07-31   8314        821     1      1             0
# 3      4          5 2015-07-31  13995       1498     1      1             0
# 4      5          5 2015-07-31   4822        559     1      1             0
#
#    SchoolHoliday  Year  ...  WeekOfYear  StoreType  Assortment  \
# 0              1  2015  ...          31          c           a
# 1              1  2015  ...          31          a           a
# 2              1  2015  ...          31          a           a
# 3              1  2015  ...          31          c           c
# 4              1  2015  ...          31          a           a
#
#   CompetitionDistance CompetitionOpenSinceMonth  CompetitionOpenSinceYear  \
# 0              1270.0                       9.0                    2008.0
# 1               570.0                      11.0                    2007.0
# 2             14130.0                      12.0                    2006.0
# 3               620.0                       9.0                    2009.0
# 4             29910.0                       4.0                    2015.0
#
#    Promo2  Promo2SinceWeek  Promo2SinceYear    PromoInterval
# 0       0              NaN              NaN              NaN
# 1       1             13.0           2010.0  Jan,Apr,Jul,Oct
# 2       1             14.0           2011.0  Jan,Apr,Jul,Oct
# 3       0              NaN              NaN              NaN
# 4       0              NaN              NaN              NaN
#
# [5 rows x 22 columns]

# %%
df_store.head()
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN

# %%
df_store.loc[df_store['Promo2']==0]
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# 5         6         a          a                310.0
# 6         7         a          c              24000.0
# ...     ...       ...        ...                  ...
# 1107   1108         a          a                540.0
# 1109   1110         c          c                900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# 5                          12.0                    2013.0       0
# 6                           4.0                    2013.0       0
# ...                         ...                       ...     ...
# 1107                        4.0                    2004.0       0
# 1109                        9.0                    2010.0       0
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
#
#       Promo2SinceWeek  Promo2SinceYear PromoInterval
# 0                 NaN              NaN           NaN
# 3                 NaN              NaN           NaN
# 4                 NaN              NaN           NaN
# 5                 NaN              NaN           NaN
# 6                 NaN              NaN           NaN
# ...               ...              ...           ...
# 1107              NaN              NaN           NaN
# 1109              NaN              NaN           NaN
# 1111              NaN              NaN           NaN
# 1112              NaN              NaN           NaN
# 1113              NaN              NaN           NaN
#
# [544 rows x 10 columns]

# %%
sns.barplot(df['Promo2'], y=df['Sales'])
# Out:
# <AxesSubplot:xlabel='Promo2', ylabel='Sales'>

# %%
no_promo2_sales = df.loc[df['Promo2']==0]['Sales'].sum()
promo2_sales = df.loc[df['Promo2']==1]['Sales'].sum()

print(f'The difference in sales of stores with no Promo2 and sales with Promo2 is {no_promo2_sales - promo2_sales}.')
# Out:
# The difference in sales of stores with no Promo2 and sales with Promo2 is 349904633.

# %% [markdown]
# **Observaation:**
#
# Here we observe that stores which didn't participate in Promo2, have NaN values in features Promo2SinceWeek/Year and PromoInterval. This simply means that no Promo2 implies that all these features have no value. Thus to indicate that we can replace NaN values in these 3 features with -1. -1 will represent that the particular store didn't participate in Promo2.
#
# It is interesting to note that the total sales of stores that didn't participate in Promo2 is greater than the total of sales of stores which participated in the Promo2. And the difference between the two is pretty big(almost 350 million units).

# %% [markdown]
# #**Conclusions of EDA**:
#
#
# *   The most selling and crowded store type is A.
#
# *   Sales is highly correlated to number of Customers.
#
# *   For all stores, Promotion leads to increase in Sales and Customers both.
#
# *   The stores which are opened during School Holiday have more sales than normal days.
#
# *   Whenever a Store participate in a Promotion, it is done for 5 days and twice a month for every store.
#
# *   More stores are opened during School holidays than State holidays.
#
# *   Sales are increased during Chirstmas week, this might be due to the fact that people buy more beauty products during a Christmas celebration.
#
# *   Absence of values in features CompetitionOpenSinceYear/Month doesn't indicate the absence of competition as CompetitionDistance values are not null where the other two values are null.
#
# *  After analysing sales using Fourier decomposition, I found that there's a seasonality component in the Sales data.

# %%
temp_df = pd.read_csv(f'./weather_data/weather.csv')
temp_df.columns
# Out:
# Index(['file', 'Date', 'Max_TemperatureC', 'Mean_TemperatureC',
#        'Min_TemperatureC', 'Dew_PointC', 'MeanDew_PointC', 'Min_DewpointC',
#        'Max_Humidity', 'Mean_Humidity', 'Min_Humidity',
#        'Max_Sea_Level_PressurehPa', 'Mean_Sea_Level_PressurehPa',
#        'Min_Sea_Level_PressurehPa', 'Max_VisibilityKm', 'Mean_VisibilityKm',
#        'Min_VisibilitykM', 'Max_Wind_SpeedKm_h', 'Mean_Wind_SpeedKm_h',
#        'Max_Gust_SpeedKm_h', 'Precipitationmm', 'CloudCover', 'Events',
#        'WindDirDegrees'],
#       dtype='object')
